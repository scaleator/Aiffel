# %% [markdown]
# # Maestro 데이터셋 전처리

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.sequence import pad_sequences

import pandas as pd
import numpy as np

import time
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import concurrent.futures

import mido

# %%
# 샘플로 1개의 MIDI 파일을 골라봅니다.
midi_file = os.getenv('HOME')+'/aiffel/music_transformer/data/maestro-v2.0.0/2018/MIDI-Unprocessed_Chamber1_MID--AUDIO_07_R3_2018_wav--2.midi'

midi = mido.MidiFile(midi_file)

# %%
ON = 1
OFF = 0
CC = 2

current_time = 0
eventlist = []
cc = False
for idx, msg in enumerate(midi):
    print('MSG [{}]----------------'.format(idx))
    current_time += msg.time
    print(current_time)
    print(msg.type)
    if msg.type is 'note_on' and msg.velocity > 0:
        event = [current_time, ON, msg.note, msg.velocity]
        print(event)
    elif msg.type is 'note_off' or (msg.type is 'note_on' and msg.velocity == 0):
        event = [current_time, OFF, msg.note, msg.velocity]
        print(event)
        
    if msg.type is 'control_change':
        if msg.control != 64:
            continue
        if cc == False and msg.value > 0:
            cc = True
            event = [current_time, CC, 0, 1]
            print(event)
        elif cc == True and msg.value == 0:
            cc = False
            event = [current_time, CC, 0, 0]
            print(event)

    if idx > 30:
        break
# Out:
# MSG [0]----------------
# 0
# set_tempo
# MSG [1]----------------
# 0
# time_signature
# MSG [2]----------------
# 0
# program_change
# MSG [3]----------------
# 0
# control_change
# MSG [4]----------------
# 0
# control_change
# MSG [5]----------------
# 0.5143229166666666
# control_change
# MSG [6]----------------
# 0.6328125
# control_change
# MSG [7]----------------
# 0.7903645833333333
# control_change
# MSG [8]----------------
# 0.9999999999999999
# control_change
# MSG [9]----------------
# 1.0325520833333333
# note_on
# [1.0325520833333333, 1, 74, 86]
# MSG [10]----------------
# 1.0442708333333333
# note_on
# [1.0442708333333333, 1, 38, 77]
# MSG [11]----------------
# 1.0794270833333333
# control_change
# MSG [12]----------------
# 1.1184895833333333
# control_change
# MSG [13]----------------
# 1.1588541666666665
# control_change
# MSG [14]----------------
# 1.2174479166666665
# control_change
# MSG [15]----------------
# 1.2265624999999998
# note_on
# [1.2265624999999998, 0, 74, 0]
# MSG [16]----------------
# 1.2369791666666665
# control_change
# MSG [17]----------------
# 1.2395833333333333
# note_on
# [1.2395833333333333, 1, 73, 69]
# MSG [18]----------------
# 1.2408854166666665
# note_on
# [1.2408854166666665, 1, 37, 64]
# MSG [19]----------------
# 1.2460937499999998
# note_on
# [1.2460937499999998, 0, 38, 0]
# MSG [20]----------------
# 1.2565104166666665
# control_change
# MSG [21]----------------
# 1.2695312499999998
# note_on
# [1.2695312499999998, 1, 34, 64]
# MSG [22]----------------
# 1.2734374999999998
# note_on
# [1.2734374999999998, 1, 71, 71]
# MSG [23]----------------
# 1.2760416666666665
# control_change
# MSG [24]----------------
# 1.2968749999999998
# control_change
# MSG [25]----------------
# 1.309895833333333
# note_on
# [1.309895833333333, 0, 34, 0]
# MSG [26]----------------
# 1.3164062499999998
# control_change
# MSG [27]----------------
# 1.3164062499999998
# note_on
# [1.3164062499999998, 0, 73, 0]
# MSG [28]----------------
# 1.3242187499999998
# note_on
# [1.3242187499999998, 1, 35, 64]
# MSG [29]----------------
# 1.3242187499999998
# note_on
# [1.3242187499999998, 0, 37, 0]
# MSG [30]----------------
# 1.3359374999999998
# control_change
# MSG [31]----------------
# 1.3437499999999998
# note_on
# [1.3437499999999998, 0, 71, 0]

# %%
IntervalDim = 100

VelocityDim = 32
VelocityOffset = IntervalDim

NoteOnDim = NoteOffDim = 128
NoteOnOffset = IntervalDim + VelocityDim
NoteOffOffset = IntervalDim + VelocityDim + NoteOnDim

CCDim = 2
CCOffset = IntervalDim + VelocityDim + NoteOnDim + NoteOffDim

EventDim = IntervalDim + VelocityDim + NoteOnDim + NoteOffDim + CCDim # 390

def get_data(data, length):    
    # time augmentation
    data[:, 0] *= np.random.uniform(0.80, 1.20)
    
    # absolute time to relative interval
    data[1:, 0] = data[1:, 0] - data[:-1, 0]
    data[0, 0] = 0
    
    # discretize interval into IntervalDim
    data[:, 0] = np.clip(np.round(data[:, 0] * IntervalDim), 0, IntervalDim - 1)
    
    # Note augmentation
    data[:, 2] += np.random.randint(-6, 6)
    data[:, 2] = np.clip(data[:, 2], 0, NoteOnDim - 1)
    
    eventlist = []
    for d in data:
        # append interval
        interval = d[0]
        eventlist.append(interval)
    
        # note on case
        if d[1] == 1:
            velocity = (d[3] / 128) * VelocityDim + VelocityOffset
            note = d[2] + NoteOnOffset
            eventlist.append(velocity)
            eventlist.append(note)
            
        # note off case
        elif d[1] == 0:
            note = d[2] + NoteOffOffset
            eventlist.append(note)
        # CC
        elif d[1] == 2:
            event = CCOffset + d[3]
            eventlist.append(event)
            
    eventlist = np.array(eventlist).astype(np.int)
    
    if len(eventlist) > (length+1):
        start_index = np.random.randint(0, len(eventlist) - (length+1))
        eventlist = eventlist[start_index:start_index+(length+1)]
        
    # pad zeros
    if len(eventlist) < (length+1):
        pad = (length+1) - len(eventlist)
        eventlist = np.pad(eventlist, (pad, 0), 'constant')
        
    x = eventlist[:length]
    y = eventlist[1:length+1]
    
    return x, y

# %% [markdown]
# # Music Transformer 모델 구현 및 학습

# %%
data_path = os.getenv('HOME')+'/aiffel/music_transformer/data/midi_test.npy'

get_midi = np.load(data_path, allow_pickle=True)
get_midi.shape
# Out:
# (1282,)

# %%
length = 256
train = []
labels = []

for midi_list in get_midi:
    cut_list = [midi_list[i:i+length] for i in range(0, len(midi_list), length)]
    for sublist in cut_list:
        x, y = get_data(np.array(sublist), length)
        train.append(x)
        labels.append(y)

# %%
train = np.array(train)
labels = np.array(labels)

print(train.shape, labels.shape)   # 학습을 위해 MIDI list를 256 길이로 나누었다.
# Out:
# (59268, 256) (59268, 256)

# %%
train_data_pad = pad_sequences(train,
                               maxlen=length,
                               padding='post',
                               value=0)
train_label_pad = pad_sequences(labels,
                                maxlen=length,
                                padding='post',
                                value=0)

# %%
def tensor_casting(train, label):
    train = tf.cast(train, tf.int64)
    label = tf.cast(label, tf.int64)

    return train, label

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_data_pad, train_label_pad))
train_dataset = train_dataset.map(tensor_casting)
train_dataset = train_dataset.shuffle(10000).batch(batch_size=16)

# %%
for t,l in train_dataset.take(1):
    print(t)
    print(l)
# Out:
# tf.Tensor(
# [[  1 116 181 ... 120 196   1]
#  [106 197   0 ... 180   1 389]
#  [  3 325   5 ...  20 119 197]
#  ...
#  [  1 342   4 ...   1 358   1]
#  [  1 111 208 ... 189   3 341]
#  [  9 113 202 ... 325  21 114]], shape=(16, 256), dtype=int64)
# tf.Tensor(
# [[116 181   2 ... 196   1 319]
#  [197   0 332 ...   1 389   1]
#  [325   5 334 ... 119 197  25]
#  ...
#  [342   4 359 ... 358   1 115]
#  [111 208   0 ...   3 341   0]
#  [113 202   1 ...  21 114 199]], shape=(16, 256), dtype=int64)

# %%
def create_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 1), tf.float32)

    # add extra dimensions to add the padding
    # to the attention logits.
    return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)


def create_look_ahead_mask(size):
    mask = tf.linalg.band_part(tf.ones((size, size)), -1, 0)
    return mask  # (seq_len, seq_len)


def point_wise_feed_forward_network(d_model, dff):
    return tf.keras.Sequential([
        tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
        tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
    ])

# %%
class RelativeGlobalAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(RelativeGlobalAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model
        self.headDim = d_model // num_heads
        self.contextDim = int(self.headDim * self.num_heads)
        self.eventDim = 390
        self.E = self.add_weight('E', shape=[self.num_heads, length, self.headDim])

        assert d_model % self.num_heads == 0

        self.wq = tf.keras.layers.Dense(self.headDim)
        self.wk = tf.keras.layers.Dense(self.headDim)
        self.wv = tf.keras.layers.Dense(self.headDim)
    
    def call(self, v, k, q, mask):
        # [Heads, Batch, Time, HeadDim]
        q = tf.stack([self.wq(q) for _ in range(self.num_heads)])
        k = tf.stack([self.wk(k) for _ in range(self.num_heads)])
        v = tf.stack([self.wv(v) for _ in range(self.num_heads)])

        self.batch_size = q.shape[1]
        self.max_len = q.shape[2]
        
        #skewing
        # E = Heads, Time, HeadDim
        # [Heads, Batch * Time, HeadDim]
        Q_ = tf.reshape(q, [self.num_heads, self.batch_size * self.max_len, self.headDim])
        # [Heads, Batch * Time, Time]
        S = tf.matmul(Q_, self.E, transpose_b=True)
        # [Heads, Batch, Time, Time]
        S = tf.reshape(S, [self.num_heads, self.batch_size, self.max_len, self.max_len])
        # [Heads, Batch, Time, Time+1]
        S = tf.pad(S, ((0, 0), (0, 0), (0, 0), (1, 0)))
        # [Heads, Batch, Time+1, Time]
        S = tf.reshape(S, [self.num_heads, self.batch_size, self.max_len + 1, self.max_len])   
        # [Heads, Batch, Time, Time]
        S = S[:, :, 1:]
        # [Heads, Batch, Time, Time]
        attention = (tf.matmul(q, k, transpose_b=True) + S) / np.sqrt(self.headDim)
        # mask tf 2.0 == tf.linalg.band_part
        get_mask = tf.linalg.band_part(tf.ones([self.max_len, self.max_len]), -1, 0)
        attention = attention * get_mask - tf.cast(1e10, attention.dtype) * (1-get_mask)
        score = tf.nn.softmax(attention, axis=3)

        # [Heads, Batch, Time, HeadDim]
        context = tf.matmul(score, v)
        # [Batch, Time, Heads, HeadDim]
        context = tf.transpose(context, [1, 2, 0, 3])
        # [Batch, Time, ContextDim]
        context = tf.reshape(context, [self.batch_size, self.max_len, self.d_model])
        # [Batch, Time, ContextDim]
        logits = tf.keras.layers.Dense(self.d_model)(context)

        return logits, score

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(EncoderLayer, self).__init__()

        self.rga = RelativeGlobalAttention(d_model, num_heads)
        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        attn_output, _ = self.rga(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)

        ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)

        return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(DecoderLayer, self).__init__()

        self.rga1 = RelativeGlobalAttention(d_model, num_heads)
        self.rga2 = RelativeGlobalAttention(d_model, num_heads)

        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        self.dropout3 = tf.keras.layers.Dropout(rate)

    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        # enc_output.shape == (batch_size, input_seq_len, d_model)

        attn1, attn_weights_block1 = self.rga1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
        attn1 = self.dropout1(attn1, training=training)
        out1 = self.layernorm1(attn1 + x)

        attn2, attn_weights_block2 = self.rga2(
            enc_output, enc_output, out1, padding_mask)  # (batch_size, target_seq_len, d_model)
        attn2 = self.dropout2(attn2, training=training)
        out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)

        ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
        ffn_output = self.dropout3(ffn_output, training=training)
        out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)

        return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, rate=0.1):
        super(Encoder, self).__init__()

        self.num_layers = num_layers
        self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) 
                           for _ in range(num_layers)]

        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        seq_len = tf.shape(x)[1]
        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x = self.enc_layers[i](x, training, mask)

        return x  # (batch_size, input_seq_len, d_model)

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, rate=0.1):
        super(Decoder, self).__init__()
        self.num_layers = num_layers
        self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) 
                           for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        attention_weights = {}
        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                                   look_ahead_mask, padding_mask)

            attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
            attention_weights['decoder_layer{}_block2'.format(i+1)] = block2

        # x.shape == (batch_size, target_seq_len, d_model)
        return x, attention_weights

# %%
class MusicTransformer(tf.keras.Model):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, rate=0.1):
        super(MusicTransformer, self).__init__()
        self.d_model = d_model
        self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)

        self.encoder = Encoder(num_layers, d_model, num_heads, dff, rate)
        self.decoder = Decoder(num_layers, d_model, num_heads, dff, rate)

        self.final_layer = tf.keras.layers.Dense(input_vocab_size)

    def call(self, inp, training, enc_padding_mask, 
             look_ahead_mask, dec_padding_mask):
        embed = self.embedding(inp)
        embed *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))

        enc_output = self.encoder(embed, training, enc_padding_mask)  # (batch_size, inp_seq_len, d_model)

        # dec_output.shape == (batch_size, tar_seq_len, d_model)
        dec_output, attention_weights = self.decoder(
            embed, enc_output, training, look_ahead_mask, dec_padding_mask)

        final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)

        return final_output, attention_weights

# %%
num_layers = 4
d_model = 128
dff = 512
num_heads = 8

input_vocab_size = 390   # MIDI가 낼 수 있는 소리의 종류
dropout_rate = 0.1

# %%
# 모델 선언
music_transformer = MusicTransformer(num_layers, d_model, num_heads, dff,
                                     input_vocab_size, rate=dropout_rate)

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()

        self.d_model = d_model
        self.d_model = tf.cast(self.d_model, tf.float32)

        self.warmup_steps = warmup_steps

    def __call__(self, step):
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps ** -1.5)

        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                     epsilon=1e-9)

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

# %%
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')

# %%
checkpoint_path = os.getenv('HOME')+'/aiffel/music_transformer/models/'

ckpt = tf.train.Checkpoint(music_transformer=music_transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print ('Latest checkpoint restored!!')
# Out:
# Latest checkpoint restored!!

# %%
#EPOCHS = 20  
EPOCHS = 5

for epoch in range(EPOCHS):
    start = time.time()

    train_loss.reset_states()

    for (batch, (inp, tar)) in enumerate(train_dataset):
        with tf.GradientTape() as tape:
            predictions, _ = music_transformer(inp, True, None, None, None)
            loss = loss_function(tar, predictions)

        gradients = tape.gradient(loss, music_transformer.trainable_variables)    
        optimizer.apply_gradients(zip(gradients, music_transformer.trainable_variables))

        train_loss(loss)

        if batch % 50 == 0:
            print ('Epoch {} Batch {} Loss {:.4f}'.format(
                epoch + 1, batch, train_loss.result()))

    if (epoch + 1) % 2 == 0:
        ckpt_save_path = ckpt_manager.save()
        print ('Saving checkpoint for epoch {} at {}'.format(epoch+1,
                                                             ckpt_save_path))

    print ('Epoch {} Loss {:.4f}'.format(epoch + 1, train_loss.result()))

    print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 3.3365
# Epoch 1 Batch 50 Loss 3.3321
# Epoch 1 Batch 100 Loss 3.3275
# Epoch 1 Batch 150 Loss 3.3223
# Epoch 1 Batch 200 Loss 3.3248
# Epoch 1 Batch 250 Loss 3.3227
# Epoch 1 Batch 300 Loss 3.3231
# Epoch 1 Batch 350 Loss 3.3217
# Epoch 1 Batch 400 Loss 3.3217
# Epoch 1 Batch 450 Loss 3.3212
# Epoch 1 Batch 500 Loss 3.3206
# Epoch 1 Batch 550 Loss 3.3215
# Epoch 1 Batch 600 Loss 3.3224
# Epoch 1 Batch 650 Loss 3.3237
# Epoch 1 Batch 700 Loss 3.3248
# Epoch 1 Batch 750 Loss 3.3253
# Epoch 1 Batch 800 Loss 3.3257
# Epoch 1 Batch 850 Loss 3.3263
# Epoch 1 Batch 900 Loss 3.3265
# Epoch 1 Batch 950 Loss 3.3267
# Epoch 1 Batch 1000 Loss 3.3270
# Epoch 1 Batch 1050 Loss 3.3270
# Epoch 1 Batch 1100 Loss 3.3271
# Epoch 1 Batch 1150 Loss 3.3268
# Epoch 1 Batch 1200 Loss 3.3273
# Epoch 1 Batch 1250 Loss 3.3274
# Epoch 1 Batch 1300 Loss 3.3275
# Epoch 1 Batch 1350 Loss 3.3276
# Epoch 1 Batch 1400 Loss 3.3278
# Epoch 1 Batch 1450 Loss 3.3282
# Epoch 1 Batch 1500 Loss 3.3283
# Epoch 1 Batch 1550 Loss 3.3278
# Epoch 1 Batch 1600 Loss 3.3278
# Epoch 1 Batch 1650 Loss 3.3274
# Epoch 1 Batch 1700 Loss 3.3276
# Epoch 1 Batch 1750 Loss 3.3275
# Epoch 1 Batch 1800 Loss 3.3279
# Epoch 1 Batch 1850 Loss 3.3281
# Epoch 1 Batch 1900 Loss 3.3287
# Epoch 1 Batch 1950 Loss 3.3290
# Epoch 1 Batch 2000 Loss 3.3293
# Epoch 1 Batch 2050 Loss 3.3296
# Epoch 1 Batch 2100 Loss 3.3293
# Epoch 1 Batch 2150 Loss 3.3291
# Epoch 1 Batch 2200 Loss 3.3291
# Epoch 1 Batch 2250 Loss 3.3292
# Epoch 1 Batch 2300 Loss 3.3295
# Epoch 1 Batch 2350 Loss 3.3296
# Epoch 1 Batch 2400 Loss 3.3298
# Epoch 1 Batch 2450 Loss 3.3299
# Epoch 1 Batch 2500 Loss 3.3298
# Epoch 1 Batch 2550 Loss 3.3300
# Epoch 1 Batch 2600 Loss 3.3300
# Epoch 1 Batch 2650 Loss 3.3303
# Epoch 1 Batch 2700 Loss 3.3302
# Epoch 1 Batch 2750 Loss 3.3305
# Epoch 1 Batch 2800 Loss 3.3307
# Epoch 1 Batch 2850 Loss 3.3307
# Epoch 1 Batch 2900 Loss 3.3305
# Epoch 1 Batch 2950 Loss 3.3306
# Epoch 1 Batch 3000 Loss 3.3306
# Epoch 1 Batch 3050 Loss 3.3307
# Epoch 1 Batch 3100 Loss 3.3307
# Epoch 1 Batch 3150 Loss 3.3307
# Epoch 1 Batch 3200 Loss 3.3308
# Epoch 1 Batch 3250 Loss 3.3306
# Epoch 1 Batch 3300 Loss 3.3305
# Epoch 1 Batch 3350 Loss 3.3304
# Epoch 1 Batch 3400 Loss 3.3303
# Epoch 1 Batch 3450 Loss 3.3304
# Epoch 1 Batch 3500 Loss 3.3305
# Epoch 1 Batch 3550 Loss 3.3305
# Epoch 1 Batch 3600 Loss 3.3305
# Epoch 1 Batch 3650 Loss 3.3305
# Epoch 1 Batch 3700 Loss 3.3304
# Epoch 1 Loss 3.3304
# Time taken for 1 epoch: 1229.4400990009308 secs
#
# Epoch 2 Batch 0 Loss 3.3081
# Epoch 2 Batch 50 Loss 3.3160
# Epoch 2 Batch 100 Loss 3.3148
# Epoch 2 Batch 150 Loss 3.3099
# Epoch 2 Batch 200 Loss 3.3110
# Epoch 2 Batch 250 Loss 3.3112
# Epoch 2 Batch 300 Loss 3.3123
# Epoch 2 Batch 350 Loss 3.3117
# Epoch 2 Batch 400 Loss 3.3133
# Epoch 2 Batch 450 Loss 3.3130
# Epoch 2 Batch 500 Loss 3.3140
# Epoch 2 Batch 550 Loss 3.3150
# Epoch 2 Batch 600 Loss 3.3149
# Epoch 2 Batch 650 Loss 3.3157
# Epoch 2 Batch 700 Loss 3.3154
# Epoch 2 Batch 750 Loss 3.3162
# Epoch 2 Batch 800 Loss 3.3168
# Epoch 2 Batch 850 Loss 3.3168
# Epoch 2 Batch 900 Loss 3.3176
# Epoch 2 Batch 950 Loss 3.3173
# Epoch 2 Batch 1000 Loss 3.3174
# Epoch 2 Batch 1050 Loss 3.3175
# Epoch 2 Batch 1100 Loss 3.3177
# Epoch 2 Batch 1150 Loss 3.3178
# Epoch 2 Batch 1200 Loss 3.3182
# Epoch 2 Batch 1250 Loss 3.3182
# Epoch 2 Batch 1300 Loss 3.3183
# Epoch 2 Batch 1350 Loss 3.3191
# Epoch 2 Batch 1400 Loss 3.3191
# Epoch 2 Batch 1450 Loss 3.3188
# Epoch 2 Batch 1500 Loss 3.3188
# Epoch 2 Batch 1550 Loss 3.3188
# Epoch 2 Batch 1600 Loss 3.3187
# Epoch 2 Batch 1650 Loss 3.3189
# Epoch 2 Batch 1700 Loss 3.3192
# Epoch 2 Batch 1750 Loss 3.3193
# Epoch 2 Batch 1800 Loss 3.3196
# Epoch 2 Batch 1850 Loss 3.3200
# Epoch 2 Batch 1900 Loss 3.3204
# Epoch 2 Batch 1950 Loss 3.3205
# Epoch 2 Batch 2000 Loss 3.3208
# Epoch 2 Batch 2050 Loss 3.3211
# Epoch 2 Batch 2100 Loss 3.3211
# Epoch 2 Batch 2150 Loss 3.3211
# Epoch 2 Batch 2200 Loss 3.3208
# Epoch 2 Batch 2250 Loss 3.3209
# Epoch 2 Batch 2300 Loss 3.3209
# Epoch 2 Batch 2350 Loss 3.3210
# Epoch 2 Batch 2400 Loss 3.3213
# Epoch 2 Batch 2450 Loss 3.3213
# Epoch 2 Batch 2500 Loss 3.3217
# Epoch 2 Batch 2550 Loss 3.3216
# Epoch 2 Batch 2600 Loss 3.3218
# Epoch 2 Batch 2650 Loss 3.3219
# Epoch 2 Batch 2700 Loss 3.3222
# Epoch 2 Batch 2750 Loss 3.3223
# Epoch 2 Batch 2800 Loss 3.3225
# Epoch 2 Batch 2850 Loss 3.3226
# Epoch 2 Batch 2900 Loss 3.3225
# Epoch 2 Batch 2950 Loss 3.3226
# Epoch 2 Batch 3000 Loss 3.3227
# Epoch 2 Batch 3050 Loss 3.3227
# Epoch 2 Batch 3100 Loss 3.3227
# Epoch 2 Batch 3150 Loss 3.3228
# Epoch 2 Batch 3200 Loss 3.3228
# Epoch 2 Batch 3250 Loss 3.3227
# Epoch 2 Batch 3300 Loss 3.3226
# Epoch 2 Batch 3350 Loss 3.3227
# Epoch 2 Batch 3400 Loss 3.3228
# Epoch 2 Batch 3450 Loss 3.3227
# Epoch 2 Batch 3500 Loss 3.3228
# Epoch 2 Batch 3550 Loss 3.3226
# Epoch 2 Batch 3600 Loss 3.3225
# Epoch 2 Batch 3650 Loss 3.3224
# Epoch 2 Batch 3700 Loss 3.3223
# Saving checkpoint for epoch 2 at /home/aiffel0011/aiffel/music_transformer/models/ckpt-11
# Epoch 2 Loss 3.3223
# Time taken for 1 epoch: 1233.5937860012054 secs
#
# Epoch 3 Batch 0 Loss 3.3085
# Epoch 3 Batch 50 Loss 3.3152
# Epoch 3 Batch 100 Loss 3.3155
# Epoch 3 Batch 150 Loss 3.3122
# Epoch 3 Batch 200 Loss 3.3123
# Epoch 3 Batch 250 Loss 3.3130
# Epoch 3 Batch 300 Loss 3.3110
# Epoch 3 Batch 350 Loss 3.3122
# Epoch 3 Batch 400 Loss 3.3118
# Epoch 3 Batch 450 Loss 3.3105
# Epoch 3 Batch 500 Loss 3.3096
# Epoch 3 Batch 550 Loss 3.3113
# Epoch 3 Batch 600 Loss 3.3121
# Epoch 3 Batch 650 Loss 3.3133
# Epoch 3 Batch 700 Loss 3.3126
# Epoch 3 Batch 750 Loss 3.3127
# Epoch 3 Batch 800 Loss 3.3137
# Epoch 3 Batch 850 Loss 3.3132
# Epoch 3 Batch 900 Loss 3.3136
# Epoch 3 Batch 950 Loss 3.3138
# Epoch 3 Batch 1000 Loss 3.3141
# Epoch 3 Batch 1050 Loss 3.3140
# Epoch 3 Batch 1100 Loss 3.3135
# Epoch 3 Batch 1150 Loss 3.3135
# Epoch 3 Batch 1200 Loss 3.3138
# Epoch 3 Batch 1250 Loss 3.3134
# Epoch 3 Batch 1300 Loss 3.3138
# Epoch 3 Batch 1350 Loss 3.3140
# Epoch 3 Batch 1400 Loss 3.3138
# Epoch 3 Batch 1450 Loss 3.3142
# Epoch 3 Batch 1500 Loss 3.3146
# Epoch 3 Batch 1550 Loss 3.3144
# Epoch 3 Batch 1600 Loss 3.3144
# Epoch 3 Batch 1650 Loss 3.3140
# Epoch 3 Batch 1700 Loss 3.3138
# Epoch 3 Batch 1750 Loss 3.3140
# Epoch 3 Batch 1800 Loss 3.3138
# Epoch 3 Batch 1850 Loss 3.3145
# Epoch 3 Batch 1900 Loss 3.3146
# Epoch 3 Batch 1950 Loss 3.3150
# Epoch 3 Batch 2000 Loss 3.3152
# Epoch 3 Batch 2050 Loss 3.3153
# Epoch 3 Batch 2100 Loss 3.3155
# Epoch 3 Batch 2150 Loss 3.3152
# Epoch 3 Batch 2200 Loss 3.3153
# Epoch 3 Batch 2250 Loss 3.3156
# Epoch 3 Batch 2300 Loss 3.3156
# Epoch 3 Batch 2350 Loss 3.3157
# Epoch 3 Batch 2400 Loss 3.3158
# Epoch 3 Batch 2450 Loss 3.3163
# Epoch 3 Batch 2500 Loss 3.3162
# Epoch 3 Batch 2550 Loss 3.3161
# Epoch 3 Batch 2600 Loss 3.3161
# Epoch 3 Batch 2650 Loss 3.3164
# Epoch 3 Batch 2700 Loss 3.3166
# Epoch 3 Batch 2750 Loss 3.3166
# Epoch 3 Batch 2800 Loss 3.3171
# Epoch 3 Batch 2850 Loss 3.3172
# Epoch 3 Batch 2900 Loss 3.3172
# Epoch 3 Batch 2950 Loss 3.3173
# Epoch 3 Batch 3000 Loss 3.3174
# Epoch 3 Batch 3050 Loss 3.3176
# Epoch 3 Batch 3100 Loss 3.3175
# Epoch 3 Batch 3150 Loss 3.3176
# Epoch 3 Batch 3200 Loss 3.3177
# Epoch 3 Batch 3250 Loss 3.3177
# Epoch 3 Batch 3300 Loss 3.3174
# Epoch 3 Batch 3350 Loss 3.3173
# Epoch 3 Batch 3400 Loss 3.3172
# Epoch 3 Batch 3450 Loss 3.3172
# Epoch 3 Batch 3500 Loss 3.3171
# Epoch 3 Batch 3550 Loss 3.3170
# Epoch 3 Batch 3600 Loss 3.3168
# Epoch 3 Batch 3650 Loss 3.3167
# Epoch 3 Batch 3700 Loss 3.3166
# Epoch 3 Loss 3.3166
# Time taken for 1 epoch: 1234.6091756820679 secs
#
# Epoch 4 Batch 0 Loss 3.3038
# Epoch 4 Batch 50 Loss 3.2958
# Epoch 4 Batch 100 Loss 3.2986
# Epoch 4 Batch 150 Loss 3.2998
# Epoch 4 Batch 200 Loss 3.3023
# Epoch 4 Batch 250 Loss 3.3010
# Epoch 4 Batch 300 Loss 3.3016
# Epoch 4 Batch 350 Loss 3.2992
# Epoch 4 Batch 400 Loss 3.3009
# Epoch 4 Batch 450 Loss 3.3011
# Epoch 4 Batch 500 Loss 3.3021
# Epoch 4 Batch 550 Loss 3.3037
# Epoch 4 Batch 600 Loss 3.3040
# Epoch 4 Batch 650 Loss 3.3047
# Epoch 4 Batch 700 Loss 3.3044
# Epoch 4 Batch 750 Loss 3.3049
# Epoch 4 Batch 800 Loss 3.3051
# Epoch 4 Batch 850 Loss 3.3055
# Epoch 4 Batch 900 Loss 3.3055
# Epoch 4 Batch 950 Loss 3.3063
# Epoch 4 Batch 1000 Loss 3.3058
# Epoch 4 Batch 1050 Loss 3.3056
# Epoch 4 Batch 1100 Loss 3.3063
# Epoch 4 Batch 1150 Loss 3.3060
# Epoch 4 Batch 1200 Loss 3.3057
# Epoch 4 Batch 1250 Loss 3.3061
# Epoch 4 Batch 1300 Loss 3.3061
# Epoch 4 Batch 1350 Loss 3.3064
# Epoch 4 Batch 1400 Loss 3.3068
# Epoch 4 Batch 1450 Loss 3.3071
# Epoch 4 Batch 1500 Loss 3.3072
# Epoch 4 Batch 1550 Loss 3.3071
# Epoch 4 Batch 1600 Loss 3.3072
# Epoch 4 Batch 1650 Loss 3.3071
# Epoch 4 Batch 1700 Loss 3.3068
# Epoch 4 Batch 1750 Loss 3.3073
# Epoch 4 Batch 1800 Loss 3.3070
# Epoch 4 Batch 1850 Loss 3.3072
# Epoch 4 Batch 1900 Loss 3.3075
# Epoch 4 Batch 1950 Loss 3.3079
# Epoch 4 Batch 2000 Loss 3.3080
# Epoch 4 Batch 2050 Loss 3.3080
# Epoch 4 Batch 2100 Loss 3.3078
# Epoch 4 Batch 2150 Loss 3.3077
# Epoch 4 Batch 2200 Loss 3.3080
# Epoch 4 Batch 2250 Loss 3.3081
# Epoch 4 Batch 2300 Loss 3.3082
# Epoch 4 Batch 2350 Loss 3.3085
# Epoch 4 Batch 2400 Loss 3.3088
# Epoch 4 Batch 2450 Loss 3.3089
# Epoch 4 Batch 2500 Loss 3.3090
# Epoch 4 Batch 2550 Loss 3.3090
# Epoch 4 Batch 2600 Loss 3.3090
# Epoch 4 Batch 2650 Loss 3.3090
# Epoch 4 Batch 2700 Loss 3.3093
# Epoch 4 Batch 2750 Loss 3.3096
# Epoch 4 Batch 2800 Loss 3.3098
# Epoch 4 Batch 2850 Loss 3.3099
# Epoch 4 Batch 2900 Loss 3.3099
# Epoch 4 Batch 2950 Loss 3.3100
# Epoch 4 Batch 3000 Loss 3.3098
# Epoch 4 Batch 3050 Loss 3.3100
# Epoch 4 Batch 3100 Loss 3.3099
# Epoch 4 Batch 3150 Loss 3.3098
# Epoch 4 Batch 3200 Loss 3.3098
# Epoch 4 Batch 3250 Loss 3.3095
# Epoch 4 Batch 3300 Loss 3.3095
# Epoch 4 Batch 3350 Loss 3.3094
# Epoch 4 Batch 3400 Loss 3.3093
# Epoch 4 Batch 3450 Loss 3.3096
# Epoch 4 Batch 3500 Loss 3.3095
# Epoch 4 Batch 3550 Loss 3.3094
# Epoch 4 Batch 3600 Loss 3.3094
# Epoch 4 Batch 3650 Loss 3.3095
# Epoch 4 Batch 3700 Loss 3.3095
# Saving checkpoint for epoch 4 at /home/aiffel0011/aiffel/music_transformer/models/ckpt-12
# Epoch 4 Loss 3.3095
# Time taken for 1 epoch: 1237.0877735614777 secs
#
# Epoch 5 Batch 0 Loss 3.2848
# Epoch 5 Batch 50 Loss 3.2980
# Epoch 5 Batch 100 Loss 3.2909
# Epoch 5 Batch 150 Loss 3.2907
# Epoch 5 Batch 200 Loss 3.2912
# Epoch 5 Batch 250 Loss 3.2935
# Epoch 5 Batch 300 Loss 3.2921
# Epoch 5 Batch 350 Loss 3.2912
# Epoch 5 Batch 400 Loss 3.2913
# Epoch 5 Batch 450 Loss 3.2931
# Epoch 5 Batch 500 Loss 3.2940
# Epoch 5 Batch 550 Loss 3.2945
# Epoch 5 Batch 600 Loss 3.2953
# Epoch 5 Batch 650 Loss 3.2958
# Epoch 5 Batch 700 Loss 3.2959
# Epoch 5 Batch 750 Loss 3.2970
# Epoch 5 Batch 800 Loss 3.2973
# Epoch 5 Batch 850 Loss 3.2977
# Epoch 5 Batch 900 Loss 3.2988
# Epoch 5 Batch 950 Loss 3.2987
# Epoch 5 Batch 1000 Loss 3.2987
# Epoch 5 Batch 1050 Loss 3.2991
# Epoch 5 Batch 1100 Loss 3.2990
# Epoch 5 Batch 1150 Loss 3.2997
# Epoch 5 Batch 1200 Loss 3.3001
# Epoch 5 Batch 1250 Loss 3.2998
# Epoch 5 Batch 1300 Loss 3.2999
# Epoch 5 Batch 1350 Loss 3.3001
# Epoch 5 Batch 1400 Loss 3.3005
# Epoch 5 Batch 1450 Loss 3.3009
# Epoch 5 Batch 1500 Loss 3.3010
# Epoch 5 Batch 1550 Loss 3.3012
# Epoch 5 Batch 1600 Loss 3.3014
# Epoch 5 Batch 1650 Loss 3.3015
# Epoch 5 Batch 1700 Loss 3.3011
# Epoch 5 Batch 1750 Loss 3.3016
# Epoch 5 Batch 1800 Loss 3.3017
# Epoch 5 Batch 1850 Loss 3.3025
# Epoch 5 Batch 1900 Loss 3.3028
# Epoch 5 Batch 1950 Loss 3.3031
# Epoch 5 Batch 2000 Loss 3.3032
# Epoch 5 Batch 2050 Loss 3.3032
# Epoch 5 Batch 2100 Loss 3.3032
# Epoch 5 Batch 2150 Loss 3.3032
# Epoch 5 Batch 2200 Loss 3.3032
# Epoch 5 Batch 2250 Loss 3.3035
# Epoch 5 Batch 2300 Loss 3.3033
# Epoch 5 Batch 2350 Loss 3.3032
# Epoch 5 Batch 2400 Loss 3.3032
# Epoch 5 Batch 2450 Loss 3.3030
# Epoch 5 Batch 2500 Loss 3.3030
# Epoch 5 Batch 2550 Loss 3.3030
# Epoch 5 Batch 2600 Loss 3.3033
# Epoch 5 Batch 2650 Loss 3.3036
# Epoch 5 Batch 2700 Loss 3.3036
# Epoch 5 Batch 2750 Loss 3.3039
# Epoch 5 Batch 2800 Loss 3.3042
# Epoch 5 Batch 2850 Loss 3.3045
# Epoch 5 Batch 2900 Loss 3.3043
# Epoch 5 Batch 2950 Loss 3.3042
# Epoch 5 Batch 3000 Loss 3.3044
# Epoch 5 Batch 3050 Loss 3.3045
# Epoch 5 Batch 3100 Loss 3.3044
# Epoch 5 Batch 3150 Loss 3.3042
# Epoch 5 Batch 3200 Loss 3.3043
# Epoch 5 Batch 3250 Loss 3.3043
# Epoch 5 Batch 3300 Loss 3.3043
# Epoch 5 Batch 3350 Loss 3.3045
# Epoch 5 Batch 3400 Loss 3.3046
# Epoch 5 Batch 3450 Loss 3.3046
# Epoch 5 Batch 3500 Loss 3.3046
# Epoch 5 Batch 3550 Loss 3.3046
# Epoch 5 Batch 3600 Loss 3.3047
# Epoch 5 Batch 3650 Loss 3.3047
# Epoch 5 Batch 3700 Loss 3.3046
# Epoch 5 Loss 3.3046
# Time taken for 1 epoch: 1220.773577928543 secs

# %% [markdown]
# # 제공된 체크포인트 파일을 이용해보기

# %%
tf.train.latest_checkpoint(checkpoint_path)
# Out:
# '/home/aiffel0011/aiffel/music_transformer/models/ckpt-12'

# %%
test_dataset = tf.data.Dataset.from_tensor_slices((train_data_pad, train_label_pad))
test_dataset = test_dataset.map(tensor_casting)
test_dataset = test_dataset.shuffle(10000).batch(batch_size=1)

# %%
N = 1000
_inputs = np.zeros([1, N], dtype=np.int32)

for x, y in test_dataset.take(1):
    _inputs[:, :length] = x[None, :]
    
for i in range(N - length):
    predictions, _ = music_transformer(_inputs[:, i:i+length], False, None, None, None)
    predictions = tf.squeeze(predictions, 0)    
    
    # select the last word from the seq_len dimension
    predicted_id = tf.random.categorical(predictions, num_samples=1)[-1,0].numpy()
    print(predicted_id)
    
    # 예측된 단어를 다음 입력으로 모델에 전달
    # 이전 은닉 상태와 함께
    _inputs[:, i+length] = predicted_id

_inputs.shape
# Out:
# 1
# 354
# 2
# 313
# 1
# 349
# 1
# 121
# 224
# 2
# 356
# 1
# 348
# 2
# 353
# 1
# 122
# 221
# 1
# 119
# 199
# 1
# 389
# 8
# 120
# 201
# 2
# 346
# 6
# 329
# 1
# 120
# 215
# 3
# 116
# 208
# 1
# 340
# 3
# 326
# 1
# 123
# 196
# 2
# 348
# 1
# 348
# 1
# 115
# 212
# 4
# 388
# 1
# 326
# 6
# 326
# 1
# 341
# 2
# 314
# 1
# 123
# 210
# 4
# 306
# 1
# 117
# 207
# 1
# 329
# 1
# 121
# 202
# 2
# 338
# 1
# 118
# 212
# 3
# 309
# 1
# 328
# 5
# 124
# 210
# 2
# 114
# 200
# 1
# 124
# 207
# 1
# 117
# 189
# 1
# 124
# 222
# 1
# 117
# 223
# 1
# 337
# 4
# 121
# 184
# 4
# 341
# 4
# 119
# 198
# 6
# 109
# 210
# 1
# 356
# 2
# 353
# 1
# 332
# 1
# 117
# 218
# 2
# 114
# 197
# 1
# 114
# 221
# 1
# 290
# 3
# 309
# 1
# 109
# 184
# 1
# 292
# 2
# 118
# 223
# 3
# 351
# 2
# 110
# 193
# 2
# 346
# 3
# 114
# 214
# 3
# 349
# 4
# 116
# 200
# 3
# 346
# 1
# 113
# 172
# 6
# 304
# 2
# 326
# 3
# 116
# 216
# 3
# 314
# 8
# 119
# 212
# 1
# 118
# 187
# 7
# 343
# 1
# 349
# 7
# 116
# 213
# 3
# 342
# 2
# 318
# 6
# 119
# 221
# 1
# 324
# 5
# 117
# 192
# 3
# 322
# 5
# 119
# 220
# 1
# 122
# 206
# 3
# 345
# 4
# 120
# 199
# 2
# 328
# 4
# 120
# 214
# 6
# 343
# 4
# 124
# 206
# 6
# 313
# 6
# 120
# 227
# 1
# 335
# 4
# 389
# 1
# 122
# 219
# 2
# 328
# 5
# 343
# 4
# 121
# 232
# 11
# 351
# 3
# 322
# 1
# 120
# 233
# 2
# 336
# 1
# 124
# 224
# 7
# 359
# 9
# 120
# 215
# 2
# 363
# 2
# 116
# 221
# 6
# 346
# 3
# 119
# 204
# 2
# 108
# 190
# 2
# 354
# 3
# 349
# 3
# 117
# 225
# 5
# 355
# 1
# 123
# 227
# 1
# 120
# 216
# 5
# 346
# 4
# 339
# 2
# 306
# 11
# 125
# 170
# 1
# 338
# 6
# 117
# 223
# 7
# 350
# 3
# 121
# 203
# 13
# 334
# 19
# 120
# 202
# 2
# 119
# 217
# 2
# 120
# 221
# 1
# 120
# 226
# 7
# 120
# 205
# 14
# 309
# 6
# 113
# 217
# 1
# 330
# 1
# 116
# 204
# 1
# 112
# 213
# 1
# 322
# 9
# 340
# 1
# 339
# 16
# 118
# 214
# 7
# 341
# 7
# 119
# 188
# 7
# 334
# 1
# 117
# 219
# 16
# 347
# 14
# 117
# 184
# 7
# 328
# 13
# 120
# 215
# 8
# 344
# 6
# 123
# 228
# 8
# 349
# 19
# 122
# 227
# 1
# 119
# 203
# 1
# 127
# 229
# 11
# 352
# 3
# 312
# 4
# 349
# 16
# 120
# 219
# 1
# 119
# 220
# 32
# 113
# 215
# 9
# 342
# 4
# 348
# 22
# 327
# 19
# 119
# 200
# 36
# 112
# 209
# 5
# 333
# 27
# 120
# 223
# 1
# 119
# 197
# 11
# 331
# 11
# 119
# 205
# 2
# 362
# 1
# 118
# 204
# 1
# 109
# 185
# 4
# 113
# 195
# 3
# 344
# 2
# 114
# 215
# 3
# 348
# 4
# 122
# 225
# 1
# 354
# 8
# 389
# 4
# 348
# 8
# 313
# 4
# 125
# 212
# 1
# 121
# 197
# 14
# 322
# 10
# 121
# 182
# 2
# 313
# 5
# 290
# 28
# 120
# 209
# 6
# 106
# 205
# 18
# 119
# 182
# 7
# 118
# 208
# 1
# 330
# 1
# 318
# 2
# 335
# 23
# 339
# 54
# 121
# 190
# 2
# 120
# 209
# 5
# 336
# 21
# 110
# 198
# 17
# 328
# 1
# 120
# 210
# 1
# 118
# 206
# 3
# 388
# 11
# 125
# 187
# 5
# 120
# 202
# 2
# 327
# 13
# 122
# 206
# 7
# 335
# 11
# 117
# 204
# 1
# 341
# 34
# 113
# 184
# 9
# 335
# 20
# 122
# 210
# 7
# 339
# 1
# 334
# 1
# 121
# 208
# 6
# 314
# 8
# 119
# 198
# 44
# 311
# 1
# 123
# 221
# 28
# 340
# 3
# 121
# 209
# 2
# 122
# 194
# 25
# 343
# 1
# 119
# 214
# 11
# 322
# 26
# 121
# 218
# 2
# 338
# 23
# 348
# 50
# 329
# 4
# 123
# 219
# 20
# 120
# 213
# 2
# 118
# 210
# 7
# 338
# 4
# 314
# 30
# 124
# 217
# 2
# 121
# 221
# 30
# 110
# 196
# 3
# 314
# 2
# 359
# 1
# 122
# 220
# 10
# 349
# 1
# 389
# 19
# 320
# 23
# 120
# 215
# 1
# 120
# 215
# 2
# 120
# 218
# 4
# 341
# 2
# 349
# 3
# 337
# 24
# 121
# 216
# 16
# 117
# 214
# 8
# 340
# 19
# 299
# 2
# 328
# 3
# 329
# 24
# 116
# 203
# 1
# 120
# 211
# 2
# 115
# 200
# 16
# 119
# 208
# 2
# 344
# 7
# 114
# 158
# 2
# 341
# 6
# 120
# 207
# 10
# 116
# 214
# 10
# 343
# 2
# 343
# 2
# 120
# 211
# 6
# 343
# 9
# 388
# 8
# 303
# 1
# 117
# 202
# 2
# 113
# 179
# 1
# 301
# 13
# 338
# 11
# 315
# 2
# 122
# 208
# 4
# 316
# 6
# 120
# 194
# 24
# 312
# 14
# 388
# 2
# 117
# 197
# 2
# 116
# 178
# 5
# 389
# 1
# 328
# 7
# 322
# 7
# 117
# 176
# 4
# 388
# 11
# 118
# 201
# 5
# 316
# 11
# 122
# 204
# 5
# 335
# 3
# 122
# 181
# 4
# 113
# 179
# 1
# 115
# 193
# 1
# 113
# 197
# 5
# 320
# 1
# 113
# 178
# 18
# 308
# 9
# 115
# 187
# 14
# 349
# (1, 1000)

# %%
class Event():
    def __init__(self, time, note, cc, on, velocity):
        self.time = time
        self.note = note
        self.on = on
        self.cc = cc
        self.velocity = velocity

    def get_event_sequence(self):
        return [self.time, self.note, int(self.on)]

class Note():
    def __init__(self):
        self.pitch = 0
        self.start_time = 0
        self.end_time = 0

# %%
event_list = []
time = 0
event = None

EventDim = IntervalDim + VelocityDim + NoteOnDim + NoteOffDim # 388

for _input in _inputs[0]:
    # interval
    if _input < IntervalDim: 
        time += _input
        event = Event(time, 0, False, 0, 0)

    # velocity
    elif _input < NoteOnOffset:
        if event is None:
            continue
        event.velocity = (_input - VelocityOffset) / VelocityDim * 128

    # note on
    elif _input < NoteOffOffset:
        if event is None:
            continue

        event.note = _input - NoteOnOffset
        event.on = True
        event_list.append(event)

        event = None

    # note off
    elif _input < CCOffset:
        if event is None:
            continue
        event.note = _input - NoteOffOffset
        event.on = False
        event_list.append(event)
        event = None

    ## CC
    else:
        if event is None:
            continue
        event.cc = True
        on = _input - CCOffset == 1
        event.on = on
        event_list.append(event)
        event = None

# %%
from mido import Message, MidiFile, MidiTrack, MetaMessage, bpm2tempo

midi = MidiFile()
output_midi_path = os.getenv('HOME')+'/aiffel/music_transformer/data/output_file.mid'

# Instantiate a MIDI Track (contains a list of MIDI events)
track = MidiTrack()
track.append(MetaMessage("set_tempo", tempo=bpm2tempo(200)))
# Append the track to the pattern
midi.tracks.append(track)

prev_time = 0
pitches = [None for _ in range(256)]
for event in event_list:
    tick = (event.time - prev_time) // 4
    midi.ticks_per_beat = 12
    prev_time = event.time

    # case NOTE:
    if not event.cc:
        if event.on:
            if pitches[event.note] is not None:
                # Instantiate a MIDI note off event, append it to the track
                off = Message('note_off', note=event.note, velocity=0, time=0)
                track.append(off)
                pitches[event.note] = None

            # Instantiate a MIDI note on event, append it to the track
            on = Message('note_on', note=event.note, velocity=int(event.velocity), time=tick)
            track.append(on)
            pitches[event.note] = prev_time
        else:
            # Instantiate a MIDI note off event, append it to the track
            off = Message('note_off', note=event.note, velocity=0, time=tick)
            track.append(off)
            pitches[event.note] = None

#     case CC:
    elif event.cc:
        if event.on:
            cc = Message('control_change', control=64, time=tick, value=127)
        else:
            cc = Message('control_change', control=64, time=tick, value=0)

        track.append(cc)

    for pitch in range(128):
        if pitches[pitch] is not None and pitches[pitch] + 200 < prev_time:
            off = Message('note_off', note=pitch, velocity=0, time=0)
            track.append(off)
            pitches[pitch] = None


# Add the end of track event, append it to the track
track.append(MetaMessage("end_of_track"))

# Save the pattern to disk
midi.save(output_midi_path)

for i, track in enumerate(midi.tracks):
    print('Track {}: {}'.format(i, track.name))
    for msg in track:
        print(msg)

print('done')
# Out:
# Track 0:
# <meta message set_tempo tempo=300000 time=0>
# note_off channel=0 note=73 velocity=0 time=0
# note_off channel=0 note=49 velocity=0 time=2
# note_on channel=0 note=51 velocity=48 time=0
# note_on channel=0 note=53 velocity=52 time=1
# note_off channel=0 note=51 velocity=0 time=0
# note_on channel=0 note=54 velocity=56 time=1
# note_off channel=0 note=53 velocity=0 time=0
# note_off channel=0 note=54 velocity=0 time=1
# note_on channel=0 note=56 velocity=52 time=0
# note_on channel=0 note=49 velocity=36 time=1
# note_on channel=0 note=66 velocity=60 time=0
# note_on channel=0 note=75 velocity=68 time=0
# note_on channel=0 note=72 velocity=68 time=0
# note_off channel=0 note=56 velocity=0 time=0
# note_off channel=0 note=72 velocity=0 time=0
# note_off channel=0 note=75 velocity=0 time=0
# note_off channel=0 note=66 velocity=0 time=0
# note_on channel=0 note=54 velocity=56 time=0
# note_off channel=0 note=54 velocity=0 time=2
# note_on channel=0 note=56 velocity=52 time=0
# note_on channel=0 note=75 velocity=64 time=0
# note_on channel=0 note=66 velocity=56 time=0
# note_on channel=0 note=72 velocity=28 time=0
# note_off channel=0 note=75 velocity=0 time=0
# note_off channel=0 note=56 velocity=0 time=0
# note_off channel=0 note=66 velocity=0 time=0
# note_off channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=57 velocity=56 time=0
# note_on channel=0 note=56 velocity=52 time=1
# note_off channel=0 note=49 velocity=0 time=0
# note_on channel=0 note=66 velocity=48 time=0
# note_off channel=0 note=57 velocity=0 time=0
# note_on channel=0 note=75 velocity=32 time=0
# note_off channel=0 note=66 velocity=0 time=0
# note_off channel=0 note=56 velocity=0 time=0
# note_off channel=0 note=75 velocity=0 time=0
# note_on channel=0 note=54 velocity=56 time=0
# note_on channel=0 note=49 velocity=44 time=2
# note_on channel=0 note=77 velocity=68 time=0
# note_off channel=0 note=54 velocity=0 time=0
# note_on channel=0 note=65 velocity=60 time=0
# note_on channel=0 note=73 velocity=44 time=0
# note_off channel=0 note=77 velocity=0 time=0
# note_off channel=0 note=65 velocity=0 time=0
# note_off channel=0 note=73 velocity=0 time=0
# note_off channel=0 note=49 velocity=0 time=3
# note_on channel=0 note=51 velocity=52 time=0
# note_on channel=0 note=53 velocity=56 time=1
# note_off channel=0 note=51 velocity=0 time=0
# note_on channel=0 note=54 velocity=56 time=1
# note_off channel=0 note=53 velocity=0 time=0
# note_off channel=0 note=54 velocity=0 time=1
# note_on channel=0 note=56 velocity=52 time=0
# note_on channel=0 note=49 velocity=44 time=1
# note_on channel=0 note=75 velocity=64 time=0
# note_on channel=0 note=66 velocity=52 time=0
# note_on channel=0 note=72 velocity=52 time=0
# note_off channel=0 note=72 velocity=0 time=0
# note_off channel=0 note=66 velocity=0 time=0
# note_off channel=0 note=75 velocity=0 time=0
# note_off channel=0 note=56 velocity=0 time=0
# note_on channel=0 note=54 velocity=52 time=0
# note_on channel=0 note=56 velocity=60 time=2
# note_on channel=0 note=66 velocity=52 time=0
# note_off channel=0 note=54 velocity=0 time=0
# note_on channel=0 note=75 velocity=64 time=0
# note_off channel=0 note=75 velocity=0 time=0
# note_off channel=0 note=66 velocity=0 time=0
# note_off channel=0 note=56 velocity=0 time=0
# note_on channel=0 note=57 velocity=52 time=1
# note_on channel=0 note=56 velocity=60 time=1
# note_off channel=0 note=57 velocity=0 time=0
# note_off channel=0 note=49 velocity=0 time=0
# note_on channel=0 note=66 velocity=56 time=0
# note_on channel=0 note=75 velocity=56 time=0
# note_off channel=0 note=75 velocity=0 time=0
# note_off channel=0 note=66 velocity=0 time=0
# note_off channel=0 note=56 velocity=0 time=0
# note_on channel=0 note=54 velocity=56 time=0
# note_off channel=0 note=54 velocity=0 time=1
# note_on channel=0 note=49 velocity=68 time=0
# note_on channel=0 note=65 velocity=76 time=0
# note_on channel=0 note=77 velocity=80 time=0
# note_on channel=0 note=73 velocity=56 time=0
# note_off channel=0 note=65 velocity=0 time=0
# note_off channel=0 note=73 velocity=0 time=0
# note_off channel=0 note=77 velocity=0 time=0
# note_on channel=0 note=53 velocity=72 time=1
# note_on channel=0 note=55 velocity=76 time=1
# note_on channel=0 note=80 velocity=96 time=0
# note_on channel=0 note=68 velocity=84 time=0
# note_off channel=0 note=80 velocity=0 time=0
# note_off channel=0 note=68 velocity=0 time=0
# note_off channel=0 note=53 velocity=0 time=0
# note_on channel=0 note=56 velocity=80 time=0
# note_off channel=0 note=55 velocity=0 time=0
# note_on channel=0 note=82 velocity=96 time=1
# note_on channel=0 note=70 velocity=96 time=0
# note_off channel=0 note=49 velocity=0 time=0
# note_on channel=0 note=55 velocity=92 time=0
# note_off channel=0 note=56 velocity=0 time=0
# note_off channel=0 note=70 velocity=0 time=0
# note_off channel=0 note=94 velocity=0 time=0
# note_off channel=0 note=53 velocity=0 time=0
# note_off channel=0 note=89 velocity=0 time=0
# note_on channel=0 note=92 velocity=84 time=0
# note_off channel=0 note=96 velocity=0 time=0
# note_off channel=0 note=88 velocity=0 time=0
# note_off channel=0 note=93 velocity=0 time=0
# note_on channel=0 note=89 velocity=88 time=0
# note_on channel=0 note=67 velocity=76 time=0
# control_change channel=0 control=64 value=127 time=0
# note_on channel=0 note=69 velocity=80 time=2
# note_off channel=0 note=86 velocity=0 time=0
# note_off channel=0 note=69 velocity=0 time=1
# note_on channel=0 note=83 velocity=80 time=0
# note_on channel=0 note=76 velocity=64 time=0
# note_off channel=0 note=80 velocity=0 time=0
# note_off channel=0 note=66 velocity=0 time=0
# note_on channel=0 note=64 velocity=92 time=0
# note_off channel=0 note=88 velocity=0 time=0
# note_off channel=0 note=88 velocity=0 time=0
# note_on channel=0 note=80 velocity=60 time=0
# control_change channel=0 control=64 value=0 time=1
# note_off channel=0 note=66 velocity=0 time=0
# note_off channel=0 note=66 velocity=0 time=1
# note_off channel=0 note=81 velocity=0 time=0
# note_off channel=0 note=54 velocity=0 time=0
# note_on channel=0 note=78 velocity=92 time=0
# note_off channel=0 note=46 velocity=0 time=1
# note_on channel=0 note=75 velocity=68 time=0
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=70 velocity=84 time=0
# note_off channel=0 note=78 velocity=0 time=0
# note_off channel=0 note=80 velocity=0 time=0
# note_on channel=0 note=80 velocity=72 time=0
# note_off channel=0 note=49 velocity=0 time=0
# note_off channel=0 note=68 velocity=0 time=0
# note_on channel=0 note=78 velocity=96 time=1
# note_on channel=0 note=68 velocity=56 time=0
# note_off channel=0 note=75 velocity=0 time=0
# note_on channel=0 note=75 velocity=96 time=0
# note_on channel=0 note=57 velocity=68 time=0
# note_on channel=0 note=90 velocity=96 time=0
# note_on channel=0 note=91 velocity=68 time=0
# note_off channel=0 note=77 velocity=0 time=0
# note_on channel=0 note=52 velocity=84 time=1
# note_off channel=0 note=81 velocity=0 time=1
# note_on channel=0 note=66 velocity=76 time=1
# note_off channel=0 note=78 velocity=0 time=0
# note_on channel=0 note=78 velocity=36 time=1
# note_off channel=0 note=96 velocity=0 time=0
# note_off channel=0 note=93 velocity=0 time=0
# note_off channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=86 velocity=68 time=0
# note_on channel=0 note=65 velocity=56 time=0
# note_off channel=0 note=89 velocity=0 time=0
# note_on channel=0 note=89 velocity=56 time=0
# note_off channel=0 note=30 velocity=0 time=0
# note_off channel=0 note=49 velocity=0 time=0
# note_off channel=0 note=52 velocity=0 time=0
# note_on channel=0 note=52 velocity=36 time=0
# note_off channel=0 note=32 velocity=0 time=0
# note_off channel=0 note=91 velocity=0 time=0
# note_on channel=0 note=91 velocity=72 time=0
# note_off channel=0 note=91 velocity=0 time=0
# note_on channel=0 note=61 velocity=40 time=0
# note_off channel=0 note=86 velocity=0 time=0
# note_off channel=0 note=82 velocity=0 time=0
# note_on channel=0 note=82 velocity=56 time=0
# note_off channel=0 note=89 velocity=0 time=0
# note_off channel=0 note=68 velocity=0 time=0
# note_on channel=0 note=68 velocity=64 time=1
# note_off channel=0 note=86 velocity=0 time=0
# note_on channel=0 note=40 velocity=52 time=0
# note_off channel=0 note=44 velocity=0 time=1
# note_off channel=0 note=66 velocity=0 time=0
# note_on channel=0 note=84 velocity=64 time=0
# note_off channel=0 note=54 velocity=0 time=0
# note_off channel=0 note=80 velocity=0 time=0
# note_on channel=0 note=80 velocity=76 time=2
# note_off channel=0 note=55 velocity=0 time=0
# note_on channel=0 note=55 velocity=72 time=0
# note_off channel=0 note=83 velocity=0 time=1
# note_off channel=0 note=89 velocity=0 time=0
# note_on channel=0 note=81 velocity=64 time=1
# note_off channel=0 note=82 velocity=0 time=0
# note_off channel=0 note=58 velocity=0 time=0
# note_on channel=0 note=89 velocity=76 time=1
# note_off channel=0 note=64 velocity=0 time=0
# note_on channel=0 note=60 velocity=68 time=1
# note_off channel=0 note=62 velocity=0 time=0
# note_on channel=0 note=88 velocity=76 time=1
# note_on channel=0 note=74 velocity=88 time=0
# note_off channel=0 note=85 velocity=0 time=0
# note_off channel=0 note=67 velocity=0 time=0
# note_on channel=0 note=67 velocity=80 time=1
# note_off channel=0 note=92 velocity=0 time=0
# note_off channel=0 note=68 velocity=0 time=0
# note_on channel=0 note=82 velocity=80 time=1
# note_off channel=0 note=83 velocity=0 time=1
# note_off channel=0 note=74 velocity=0 time=0
# note_on channel=0 note=74 velocity=96 time=1
# note_off channel=0 note=53 velocity=0 time=1
# note_on channel=0 note=95 velocity=80 time=1
# note_off channel=0 note=76 velocity=0 time=0
# note_off channel=0 note=75 velocity=0 time=0
# control_change channel=0 control=64 value=127 time=1
# note_on channel=0 note=87 velocity=88 time=0
# note_off channel=0 note=68 velocity=0 time=0
# note_off channel=0 note=83 velocity=0 time=1
# note_on channel=0 note=100 velocity=84 time=1
# note_off channel=0 note=91 velocity=0 time=2
# note_off channel=0 note=70 velocity=0 time=0
# note_off channel=0 note=62 velocity=0 time=0
# note_on channel=0 note=101 velocity=80 time=0
# note_off channel=0 note=76 velocity=0 time=0
# note_on channel=0 note=92 velocity=96 time=0
# note_off channel=0 note=99 velocity=0 time=1
# note_on channel=0 note=83 velocity=80 time=2
# note_off channel=0 note=57 velocity=0 time=0
# note_off channel=0 note=90 velocity=0 time=0
# note_off channel=0 note=103 velocity=0 time=0
# note_off channel=0 note=89 velocity=0 time=0
# note_on channel=0 note=89 velocity=64 time=0
# note_off channel=0 note=86 velocity=0 time=1
# note_on channel=0 note=72 velocity=76 time=0
# note_on channel=0 note=58 velocity=32 time=0
# note_off channel=0 note=78 velocity=0 time=0
# note_off channel=0 note=94 velocity=0 time=0
# note_off channel=0 note=89 velocity=0 time=0
# note_on channel=0 note=93 velocity=68 time=0
# note_off channel=0 note=65 velocity=0 time=0
# note_off channel=0 note=95 velocity=0 time=1
# note_off channel=0 note=52 velocity=0 time=0
# note_on channel=0 note=95 velocity=92 time=0
# note_off channel=0 note=84 velocity=0 time=0
# note_on channel=0 note=84 velocity=80 time=0
# note_off channel=0 note=86 velocity=0 time=1
# note_off channel=0 note=61 velocity=0 time=0
# note_off channel=0 note=79 velocity=0 time=1
# note_off channel=0 note=46 velocity=0 time=0
# note_on channel=0 note=38 velocity=100 time=2
# note_off channel=0 note=40 velocity=0 time=0
# note_off channel=0 note=78 velocity=0 time=0
# note_on channel=0 note=91 velocity=68 time=1
# note_off channel=0 note=90 velocity=0 time=1
# note_on channel=0 note=71 velocity=84 time=0
# note_off channel=0 note=74 velocity=0 time=3
# note_off channel=0 note=55 velocity=0 time=0
# note_off channel=0 note=80 velocity=0 time=0
# note_on channel=0 note=70 velocity=80 time=4
# note_off channel=0 note=81 velocity=0 time=0
# note_on channel=0 note=85 velocity=76 time=0
# note_on channel=0 note=89 velocity=80 time=0
# note_on channel=0 note=94 velocity=80 time=0
# note_off channel=0 note=60 velocity=0 time=0
# note_on channel=0 note=73 velocity=80 time=1
# note_off channel=0 note=49 velocity=0 time=3
# note_off channel=0 note=67 velocity=0 time=0
# note_off channel=0 note=88 velocity=0 time=0
# note_off channel=0 note=85 velocity=0 time=0
# note_on channel=0 note=85 velocity=52 time=1
# note_off channel=0 note=82 velocity=0 time=0
# note_off channel=0 note=70 velocity=0 time=0
# note_off channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=72 velocity=64 time=0
# note_on channel=0 note=81 velocity=48 time=0
# note_off channel=0 note=62 velocity=0 time=0
# note_off channel=0 note=80 velocity=0 time=2
# note_off channel=0 note=79 velocity=0 time=0
# note_on channel=0 note=82 velocity=72 time=4
# note_off channel=0 note=87 velocity=0 time=0
# note_off channel=0 note=81 velocity=0 time=1
# note_off channel=0 note=100 velocity=0 time=0
# note_on channel=0 note=56 velocity=76 time=1
# note_off channel=0 note=74 velocity=0 time=1
# note_off channel=0 note=101 velocity=0 time=0
# note_on channel=0 note=87 velocity=68 time=0
# note_off channel=0 note=92 velocity=0 time=0
# note_off channel=0 note=87 velocity=0 time=4
# note_off channel=0 note=83 velocity=0 time=0
# note_on channel=0 note=52 velocity=68 time=3
# note_off channel=0 note=68 velocity=0 time=1
# note_off channel=0 note=58 velocity=0 time=0
# note_on channel=0 note=83 velocity=80 time=3
# note_off channel=0 note=84 velocity=0 time=0
# note_off channel=0 note=93 velocity=0 time=0
# note_off channel=0 note=95 velocity=0 time=0
# note_off channel=0 note=84 velocity=0 time=2
# note_on channel=0 note=96 velocity=92 time=1
# note_off channel=0 note=89 velocity=0 time=2
# note_off channel=0 note=38 velocity=0 time=0
# note_on channel=0 note=95 velocity=88 time=4
# note_off channel=0 note=71 velocity=0 time=0
# note_off channel=0 note=91 velocity=0 time=0
# note_on channel=0 note=71 velocity=76 time=0
# note_on channel=0 note=97 velocity=108 time=0
# note_off channel=0 note=92 velocity=0 time=2
# note_off channel=0 note=52 velocity=0 time=0
# note_off channel=0 note=89 velocity=0 time=1
# note_on channel=0 note=87 velocity=80 time=4
# note_off channel=0 note=94 velocity=0 time=0
# note_on channel=0 note=88 velocity=76 time=0
# note_off channel=0 note=83 velocity=0 time=0
# note_on channel=0 note=83 velocity=52 time=8
# note_off channel=0 note=72 velocity=0 time=0
# note_off channel=0 note=73 velocity=0 time=0
# note_off channel=0 note=85 velocity=0 time=0
# note_off channel=0 note=82 velocity=0 time=2
# note_off channel=0 note=88 velocity=0 time=1
# note_off channel=0 note=67 velocity=0 time=5
# note_off channel=0 note=56 velocity=0 time=0
# note_on channel=0 note=68 velocity=76 time=4
# note_on channel=0 note=77 velocity=48 time=9
# note_off channel=0 note=73 velocity=0 time=1
# note_on channel=0 note=91 velocity=80 time=6
# note_off channel=0 note=96 velocity=0 time=0
# note_on channel=0 note=65 velocity=76 time=0
# note_off channel=0 note=71 velocity=0 time=2
# note_off channel=0 note=95 velocity=0 time=0
# note_off channel=0 note=97 velocity=0 time=0
# note_on channel=0 note=73 velocity=76 time=2
# note_off channel=0 note=102 velocity=0 time=0
# note_on channel=0 note=72 velocity=72 time=0
# note_on channel=0 note=53 velocity=36 time=0
# note_on channel=0 note=63 velocity=52 time=1
# note_off channel=0 note=84 velocity=0 time=0
# note_off channel=0 note=83 velocity=0 time=0
# note_on channel=0 note=83 velocity=56 time=0
# note_off channel=0 note=88 velocity=0 time=0
# note_on channel=0 note=93 velocity=88 time=1
# note_off channel=0 note=94 velocity=0 time=0
# control_change channel=0 control=64 value=127 time=2
# note_off channel=0 note=87 velocity=0 time=0
# note_off channel=0 note=88 velocity=0 time=1
# note_off channel=0 note=53 velocity=0 time=2
# note_on channel=0 note=80 velocity=100 time=1
# note_off channel=0 note=65 velocity=0 time=0
# note_on channel=0 note=65 velocity=84 time=0
# note_off channel=0 note=62 velocity=0 time=3
# note_on channel=0 note=50 velocity=84 time=2
# note_off channel=0 note=53 velocity=0 time=0
# note_off channel=0 note=30 velocity=0 time=1
# note_off channel=0 note=77 velocity=0 time=0
# note_on channel=0 note=77 velocity=80 time=7
# note_off channel=0 note=73 velocity=0 time=0
# note_on channel=0 note=73 velocity=24 time=1
# note_off channel=0 note=68 velocity=0 time=0
# note_off channel=0 note=50 velocity=0 time=0
# note_on channel=0 note=50 velocity=76 time=4
# note_on channel=0 note=76 velocity=72 time=1
# note_off channel=0 note=70 velocity=0 time=0
# note_off channel=0 note=58 velocity=0 time=0
# note_off channel=0 note=75 velocity=0 time=0
# note_off channel=0 note=79 velocity=0 time=5
# note_on channel=0 note=58 velocity=84 time=13
# note_off channel=0 note=63 velocity=0 time=0
# note_off channel=0 note=72 velocity=0 time=0
# note_off channel=0 note=83 velocity=0 time=0
# note_off channel=0 note=91 velocity=0 time=0
# note_off channel=0 note=77 velocity=0 time=0
# note_on channel=0 note=77 velocity=80 time=0
# note_off channel=0 note=76 velocity=0 time=1
# note_off channel=0 note=93 velocity=0 time=0
# note_on channel=0 note=66 velocity=40 time=5
# note_off channel=0 note=68 velocity=0 time=4
# note_off channel=0 note=65 velocity=0 time=0
# note_off channel=0 note=80 velocity=0 time=0
# note_on channel=0 note=78 velocity=80 time=0
# note_on channel=0 note=74 velocity=72 time=0
# control_change channel=0 control=64 value=0 time=0
# note_on channel=0 note=55 velocity=100 time=2
# note_on channel=0 note=70 velocity=80 time=1
# note_off channel=0 note=67 velocity=0 time=0
# note_off channel=0 note=74 velocity=0 time=0
# note_on channel=0 note=74 velocity=88 time=3
# note_off channel=0 note=75 velocity=0 time=1
# note_on channel=0 note=72 velocity=68 time=2
# note_off channel=0 note=73 velocity=0 time=0
# note_off channel=0 note=81 velocity=0 time=0
# note_on channel=0 note=52 velocity=52 time=8
# note_off channel=0 note=50 velocity=0 time=0
# note_off channel=0 note=75 velocity=0 time=2
# note_off channel=0 note=78 velocity=0 time=0
# note_on channel=0 note=78 velocity=88 time=5
# note_off channel=0 note=79 velocity=0 time=1
# note_off channel=0 note=74 velocity=0 time=0
# note_on channel=0 note=76 velocity=84 time=0
# note_off channel=0 note=54 velocity=0 time=1
# note_off channel=0 note=66 velocity=0 time=0
# note_on channel=0 note=66 velocity=76 time=2
# note_off channel=0 note=51 velocity=0 time=11
# note_off channel=0 note=58 velocity=0 time=0
# note_off channel=0 note=77 velocity=0 time=0
# note_on channel=0 note=89 velocity=92 time=0
# note_off channel=0 note=80 velocity=0 time=7
# note_on channel=0 note=77 velocity=84 time=0
# note_off channel=0 note=55 velocity=0 time=0
# note_on channel=0 note=62 velocity=88 time=0
# note_off channel=0 note=83 velocity=0 time=6
# note_off channel=0 note=70 velocity=0 time=0
# note_on channel=0 note=82 velocity=76 time=0
# note_off channel=0 note=62 velocity=0 time=2
# note_off channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=86 velocity=84 time=6
# note_off channel=0 note=78 velocity=0 time=0
# note_off channel=0 note=88 velocity=0 time=5
# note_off channel=0 note=52 velocity=0 time=0
# note_off channel=0 note=69 velocity=0 time=12
# note_off channel=0 note=66 velocity=0 time=0
# note_off channel=0 note=76 velocity=0 time=0
# note_on channel=0 note=87 velocity=92 time=1
# note_on channel=0 note=81 velocity=80 time=5
# note_on channel=0 note=78 velocity=72 time=0
# note_off channel=0 note=78 velocity=0 time=1
# note_off channel=0 note=89 velocity=0 time=0
# note_off channel=0 note=54 velocity=0 time=1
# note_on channel=0 note=85 velocity=96 time=7
# note_off channel=0 note=77 velocity=0 time=0
# note_on channel=0 note=89 velocity=84 time=0
# note_on channel=0 note=64 velocity=40 time=7
# note_off channel=0 note=82 velocity=0 time=0
# note_off channel=0 note=54 velocity=0 time=0
# note_off channel=0 note=99 velocity=0 time=0
# note_on channel=0 note=88 velocity=88 time=0
# note_off channel=0 note=89 velocity=0 time=2
# control_change channel=0 control=64 value=127 time=0
# note_off channel=0 note=60 velocity=0 time=4
# note_off channel=0 note=86 velocity=0 time=0
# note_on channel=0 note=83 velocity=80 time=5
# note_off channel=0 note=83 velocity=0 time=0
# note_on channel=0 note=83 velocity=80 time=0
# note_on channel=0 note=86 velocity=80 time=0
# note_off channel=0 note=81 velocity=0 time=1
# note_off channel=0 note=89 velocity=0 time=0
# note_off channel=0 note=77 velocity=0 time=0
# note_on channel=0 note=84 velocity=84 time=6
# note_on channel=0 note=82 velocity=68 time=4
# note_off channel=0 note=87 velocity=0 time=0
# note_off channel=0 note=80 velocity=0 time=2
# note_off channel=0 note=39 velocity=0 time=4
# note_off channel=0 note=68 velocity=0 time=0
# note_off channel=0 note=69 velocity=0 time=0
# note_on channel=0 note=71 velocity=64 time=6
# note_on channel=0 note=79 velocity=80 time=0
# note_on channel=0 note=68 velocity=60 time=0
# note_off channel=0 note=85 velocity=0 time=0
# note_on channel=0 note=76 velocity=76 time=4
# note_off channel=0 note=84 velocity=0 time=0
# note_on channel=0 note=26 velocity=56 time=1
# note_off channel=0 note=81 velocity=0 time=0
# note_on channel=0 note=75 velocity=80 time=1
# note_off channel=0 note=64 velocity=0 time=0
# note_off channel=0 note=82 velocity=0 time=0
# note_on channel=0 note=82 velocity=64 time=2
# note_off channel=0 note=88 velocity=0 time=0
# note_off channel=0 note=83 velocity=0 time=2
# note_off channel=0 note=83 velocity=0 time=0
# note_off channel=0 note=79 velocity=0 time=0
# note_on channel=0 note=79 velocity=80 time=0
# note_off channel=0 note=83 velocity=0 time=1
# control_change channel=0 control=64 value=0 time=2
# note_off channel=0 note=43 velocity=0 time=2
# note_on channel=0 note=70 velocity=68 time=0
# note_on channel=0 note=47 velocity=52 time=0
# note_off channel=0 note=41 velocity=0 time=0
# note_off channel=0 note=78 velocity=0 time=3
# note_off channel=0 note=86 velocity=0 time=0
# note_off channel=0 note=55 velocity=0 time=2
# note_off channel=0 note=76 velocity=0 time=0
# note_on channel=0 note=76 velocity=88 time=0
# note_off channel=0 note=56 velocity=0 time=1
# note_on channel=0 note=62 velocity=80 time=1
# note_off channel=0 note=52 velocity=0 time=6
# control_change channel=0 control=64 value=0 time=3
# note_on channel=0 note=65 velocity=68 time=0
# note_on channel=0 note=46 velocity=64 time=0
# control_change channel=0 control=64 value=127 time=1
# note_off channel=0 note=68 velocity=0 time=0
# note_off channel=0 note=62 velocity=0 time=1
# note_on channel=0 note=44 velocity=68 time=1
# control_change channel=0 control=64 value=0 time=1
# note_on channel=0 note=69 velocity=72 time=2
# note_off channel=0 note=56 velocity=0 time=1
# note_off channel=0 note=71 velocity=0 time=0
# note_on channel=0 note=72 velocity=88 time=2
# note_off channel=0 note=75 velocity=0 time=1
# note_on channel=0 note=49 velocity=88 time=0
# note_off channel=0 note=47 velocity=0 time=0
# note_on channel=0 note=47 velocity=52 time=1
# note_on channel=0 note=61 velocity=60 time=0
# note_off channel=0 note=26 velocity=0 time=0
# note_off channel=0 note=65 velocity=0 time=0
# note_on channel=0 note=65 velocity=52 time=0
# note_off channel=0 note=60 velocity=0 time=1
# note_off channel=0 note=46 velocity=0 time=0
# note_on channel=0 note=46 velocity=52 time=0
# note_off channel=0 note=48 velocity=0 time=4
# note_off channel=0 note=82 velocity=0 time=0
# note_on channel=0 note=55 velocity=60 time=2
# note_off channel=0 note=79 velocity=0 time=0
# note_off channel=0 note=89 velocity=0 time=3
# <meta message end_of_track time=0>
# done

# %% [markdown]
# # tempo , tick, ticks per beat 부분을 변경하였음
# # output file URL :
# https://github.com/scaleator/Aiffel/blob/master/output_file.mid
